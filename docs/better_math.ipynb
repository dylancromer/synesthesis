# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib
matplotlib.rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True
matplotlib.rcParams['figure.dpi']= 150
#matplotlib.rcParams['figure.figsize'] = [7, 7]
import matplotlib.pyplot as plt
matplotlib.rcParams.update({'figure.autolayout': True})
import seaborn as sns
# Out:
# /Users/dylan/Development/synesthesis/venv-synesthesis/lib/python3.7/site-packages/matplotlib/__init__.py:846: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   "2.2", name=key, obj_type="rcparam", addendum=addendum)

# %%
sns.set(style='whitegrid', font_scale=0.7, rc={"lines.linewidth": 1,
                                               'lines.markersize': 1.}, font="serif")

# %%
from synesthesis.utils import load_image_file
import numpy as np

# %%
smile = load_image_file('/Users/dylan/Downloads/smile.png', False)

# %%
plt.imshow(smile, cmap="binary_r")
plt.grid(b=None)

# %%
import scipy.signal as sig

# %%
duration = 10
framerate = 100000 #smile.size//duration
time_signal = sig.istft(smile, fs=framerate, time_axis=0, freq_axis=1)#, nperseg=10000, nfft=10000)

# %%
plt.plot(time_signal[0], time_signal[1])
#plt.xlim(4.4,4.401)
# Out:
# /Users/dylan/Development/synesthesis/venv-synesthesis/lib/python3.7/site-packages/matplotlib/figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
freq_signal = sig.stft(time_signal[1], fs=framerate)

# %%
freqs,times,inv_im = freq_signal

# %%
plt.imshow(np.abs(inv_im.T), cmap="binary_r", aspect='auto')
plt.grid(b=None)

# %%
processed_time_signal = None

# %%
processed_time_signal.max()

# %%
plt.plot(time_signal[0], processed_time_signal)
plt.xlim(2,2.005)

# %%
prepros_freq_signal = sig.stft(processed_time_signal, fs=framerate)
prepros_freqs,prepros_times,prepros_inv_im = prepros_freq_signal

# %%
plt.imshow(np.abs(prepros_inv_im.T), cmap="binary_r", aspect='auto')
plt.grid(b=None)
